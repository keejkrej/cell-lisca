# %%
import numpy as np
import matplotlib.pyplot as plt
import yaml

# %%
arr = np.load("fov_001/fov_001_pattern_004_seq_000.npy")

# %%
arr.shape
# Out:
# (37, 5, 72, 124)

# %%
with open("fov_001/fov_001_pattern_004_seq_000.yaml", "r") as f:
    titles = yaml.safe_load(f)['channels']

# %%
fig, axs = plt.subplots(1,5, figsize=(16, 4))
for i in range(5):
    ax = axs[i]
    ax.imshow(arr[30,i])
    ax.axis("off")
    ax.set_title(titles[i])
